# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %% [markdown]
# # Good Ones

# %%
# N = 8 Z = 8 O16
x = [0, 0.04, 0.08, 0.12, 0.16]
y = [-76.1367, -76.1368, -76.1371, -76.1376, -76.1383]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0] 
print res
#0.0612 from density
# Out:
# -0.06249999999529409

# %%
# N = 20, Z = 20 Ca40
x = [0, 0.04, 0.08, 0.12, 0.16]
y = [-246.009555, -246.009881, -246.010858, -246.012486, -246.014766]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#0.2037 from density
# Out:
# -0.20352678571620225

# %%
# N = 28, Z = 28 Ni56
x = [0, 0.04, 0.08, 0.12, 0.16]
y = [-372.940883, -372.941272, -372.942439, -372.944383, -372.947106]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#0.2431 from density
# Out:
# -0.24308035713543302

# %%
# N = 14, Z = 14 Si28
x = [0, 0.04, 0.08, 0.12, 0.16]
y = [-164.089558, -164.089708, -164.090156, -164.090903, -164.09195]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#0.0934 from density
# Out:
# -0.09343749999090202

# %%
# Ti 100
# N = 50, Z = 50
x = [0, 0.04, 0.08, 0.12, 0.16]
y = [-656.22878, -656.229721, -656.232541, -656.237238, -656.243826]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#0.5893
# Out:
# -0.5879910714187908

# %%
# Zr80(L = 3) sort of works
# N = 40 , Z = 40
x = [0, 0.04, 0.08, 0.12, 0.16]
y = [-501.76699, -501.767865, -501.77049, -501.774866, -501.780991]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#0.5524 from density
# Out:
# -0.5469196428363388

# %% [markdown]
# # Bad Ones

# %%
# N = 18, Z = 18 Ar36
# x = [0, 0.04, 0.08, 0.12, 0.16]
# y = [-214.982825, -212.400128, -212.401105, -212.402732, -212.405012]
x = [0.04, 0.08, 0.12, 0.16]
y = [-212.400128, -212.401105, -212.402732, -212.405012]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#0.2037 from density

# %%
# Be8
# N = 4, Z = 4
# x = [0, 0.04, 0.08, 0.12, 0.16]
# y = [-9.67140719, -14.1473179, -14.1475845, -14.1480288, -14.1486509]
x = [0.04, 0.08, 0.12, 0.16]
y = [-14.1473179, -14.1475845, -14.1480288, -14.1486509]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#0.0555 from density

# %%
#Ca48
# N = 28, Z = 20 Ca48
x = [0, 0.04, 0.08, 0.12, 0.16]
y = [-313.705605, -313.707465, -313.713046, -313.722349, -313.735365]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#0.6967 from density

# %%
# Ni68
# N = 40
# Z = 28
# L = 1 : -6.85057269 Z/A
x = [0, 0.04, 0.08, 0.12, 0.16]
y = [-458.305235, -458.3091, -458.320695, -458.342729, -458.369798]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]
test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#from density 1.4578

# %% [markdown]
# # Testing

# %%
def plotEnergy(name):
    f = open(name)
    energies = []
    for i in f:
        energies.append(float(i))
    energiesStable = np.array(energies[35:])
    energiesStable -= np.mean(energiesStable)
#     plt.plot(range(len(energies)), energies, 'b.')
#     print energies
    plt.plot(range(len(energiesStable)), energiesStable, 'b.')

# %%
plotEnergy("energies40.txt")

# %%
plotEnergy("energies48.txt")

# %%
plotEnergy("energies68.txt")

# %%
plotEnergy("energies100.txt")

# %%
plotEnergy("energies208.txt")

# %%
plotEnergy("totalenergies0.000000.txt")

# %% [markdown]
# # Adjust Nodes

# %%
# N = 20, Z = 20 Ca40(with 15 nodes)
x = [0, 0.04, 0.08, 0.12, 0.16]
y = [-246.003718, -246.004043, -246.00502, -246.006648, -246.008928]
ret1 = np.polyfit(x, y, 2)
def generate(array):
    x = np.linspace(0, 0.2, 100)
    return x, [array[2] + array[1] * i + array[0] * i** 2 for i in x]

test = generate(ret1)
plt.plot(x, y,'r.', test[0], test[1], 'g-')
res = np.polyfit(x, y, 2)[0]
print res
#0.2037 from density
# Out:
# -0.20361607143462776
